# %% [markdown]
# 在 Jupyter Notebook 中导入 utils

# %%
# 确保能正确导入
import sys
import os
project_root = os.path.abspath(os.path.join('..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.utils import describe_data, plot_vibration_trend, filter_3sigma

# %% [markdown]
# 函数使用示例

# %%
# 1. 数据描述
stats = describe_data(your_dataframe)

# 2. 绘制趋势图（指定设备）
fig = plot_vibration_trend(
    df=your_dataframe,
    device_id='DEV-101',
    time_window='6H',
    save_path='../figures/trend_DEV101.png'
)

# 3. 过滤异常值（按设备分组处理，推荐）
filtered_df, stats_info = filter_3sigma(
    df=your_dataframe,
    columns=['vibration_x', 'vibration_y', 'vibration_z'],
    group_by_device=True,
    return_stats=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 1. 数据描述
# ----> 2 stats = describe_data(your_dataframe)
#       4 # 2. 绘制趋势图（指定设备）
#       5 fig = plot_vibration_trend(
#       6     df=your_dataframe,
#       7     device_id='DEV-101',
#       8     time_window='6H',
#       9     save_path='../figures/trend_DEV101.png'
#      10 )
#
# NameError: name 'your_dataframe' is not defined
